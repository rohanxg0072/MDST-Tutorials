# %% [markdown]
# <h1> Checkpoint:</h1>
#
# **Looking to see completetion and effort in completing the checkpoint. It's okay if it's not correct**
#
# Based off this dataset with school financial, enrollment, and achievement data, we are interested in what information is a useful indicator of student performance at the state level.
#
# This question is a bit too big for a checkpoint, however. Instead, we want you to look at smaller questions related to our overall goal. Here's the overview:
#
# 1. Choose a specific test to focus on
# >Math/Reading for 4/8 grade
# * Pick or create features to use
# >Will all the features be useful in predicting test score? Are some more important than others? Should you standardize, bin, or scale the data?
# * Explore the data as it relates to that test
# >Create 2 well-labeled visualizations (graphs), each with a caption describing the graph and what it tells us about the data
# * Create training and testing data
# >Do you want to train on all the data? Only data from the last 10 years? Only Michigan data?
# * Train a ML model to predict outcome
# >Pick if you want to do a regression or classification task. For both cases, defined _exactly_ what you want to predict, and pick any model in sklearn to use (see sklearn <a href="https://scikit-learn.org/stable/modules/linear_model.html">regressors</a> and <a href="https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html">classifiers</a>).
# * Summarize your findings
# >Write a 1 paragraph summary of what you did and make a recommendation about if and how student performance can be predicted
#
# ** Include comments throughout your code! Every cleanup and preprocessing task should be documented.
#
#
# Of course, if you're finding this assignment interesting (and we really hope you do!), you are welcome to do more than the requirements! For example, you may want to see if expenditure affects 4th graders more than 8th graders. Maybe you want to look into the extended version of this dataset and see how factors like sex and race are involved. You can include all your work in this notebook when you turn it in -- just always make sure you explain what you did and interpret your results. Good luck!

# %% [markdown]
# <h2> Data Cleanup </h2>
#
# Import numpy, pandas, matplotlib, and seaborn
#
# (Feel free to import other libraries!)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load in the "states_edu.csv" dataset and take a look at the head of the data

# %%
# reading file

df = pd.read_csv('../data/states_edu.csv')
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %% [markdown]
# You should always familiarize yourself with what each column in the dataframe represents. \ Read about the states_edu dataset here: https://www.kaggle.com/noriuk/us-education-datasets-unification-project

# %% [markdown]
# Use this space to rename columns, deal with missing data, etc. _(optional)_

# %% [markdown]
# <h2>Exploratory Data Analysis (EDA) </h2>

# %% [markdown]
# Chosen Outcome Variable for Test: **<Math for 8 grade>**   (Ex. Math for 8th grade)
#
# **(hit `Enter` to edit)**
#
# Outcome Score in the questions refers to the outcome variable you chose here.

# %% [markdown]
# How many different years of data are in our dataset? Use a pandas function.

# %%
len(df["YEAR"].unique())
# Out:
# 33

# %% [markdown]
# Let's compare Michigan to Ohio. Which state has the higher average outcome score across all years?

# %%
# grouping data by state
by_state = df.groupby("STATE")
by_state["AVG_MATH_8_SCORE"].mean()

# finding difference between mich and ohio avg
by_state["AVG_MATH_8_SCORE"].mean()["MICHIGAN"]- by_state["AVG_MATH_8_SCORE"].mean()["OHIO"]

# Ohio has the higher average outcome :(
# Out:
# -6.083333333333314

# %% [markdown]
# Find the average for your outcome score across all states in 2019

# %%
# selecting only rows from year 2019
df_2019 = df[df["YEAR"] == 2019]
df_2019["AVG_MATH_8_SCORE"].mean()
# Out:
# 281.2641509433962

# %% [markdown]
# Find the maximum outcome score for every state. Hint: there's a function that allows you to do this easily

# %%
# grouping by state
by_state = df.groupby("STATE")
by_state["AVG_MATH_8_SCORE"].max()
# Out:
# STATE
# ALABAMA                 269.0
# ALASKA                  283.0
# ARIZONA                 283.0
# ARKANSAS                279.0
# CALIFORNIA              277.0
# COLORADO                292.0
# CONNECTICUT             289.0
# DELAWARE                284.0
# DISTRICT_OF_COLUMBIA    269.0
# DODEA                   293.0
# FLORIDA                 281.0
# GEORGIA                 281.0
# HAWAII                  281.0
# IDAHO                   287.0
# ILLINOIS                285.0
# INDIANA                 288.0
# IOWA                    286.0
# KANSAS                  290.0
# KENTUCKY                282.0
# LOUISIANA               273.0
# MAINE                   289.0
# MARYLAND                288.0
# MASSACHUSETTS           301.0
# MICHIGAN                280.0
# MINNESOTA               295.0
# MISSISSIPPI             274.0
# MISSOURI                286.0
# MONTANA                 293.0
# NATIONAL                285.0
# NEBRASKA                288.0
# NEVADA                  278.0
# ...

# %% [markdown]
# <h2> Feature Selection </h2>
#
# After exploring the data, you now have to choose features that you would use to predict the performance of the students on a chosen test (chosen outcome variable). By the way, you can also create your own features. For example, perhaps you figured that maybe a state's expenditure per student may affect their overall academic performance so you create a expenditure_per_student feature.
#
# Use this space to modify or create features

# %%
# checking to see what features I have

df.columns.tolist()
# Out:
# ['PRIMARY_KEY',
#  'STATE',
#  'YEAR',
#  'ENROLL',
#  'TOTAL_REVENUE',
#  'FEDERAL_REVENUE',
#  'STATE_REVENUE',
#  'LOCAL_REVENUE',
#  'TOTAL_EXPENDITURE',
#  'INSTRUCTION_EXPENDITURE',
#  'SUPPORT_SERVICES_EXPENDITURE',
#  'OTHER_EXPENDITURE',
#  'CAPITAL_OUTLAY_EXPENDITURE',
#  'GRADES_PK_G',
#  'GRADES_KG_G',
#  'GRADES_4_G',
#  'GRADES_8_G',
#  'GRADES_12_G',
#  'GRADES_1_8_G',
#  'GRADES_9_12_G',
#  'GRADES_ALL_G',
#  'AVG_MATH_4_SCORE',
#  'AVG_MATH_8_SCORE',
#  'AVG_READING_4_SCORE',
#  'AVG_READING_8_SCORE']

# %% [markdown]
# Final feature list: instruction expenditure, support expenditure, capital outlay expenditure

# %% [markdown]
# Feature selection justification:
#
# Instruction expenditure could likely impact average math score, for increased spending might mean better instruction. Similarly, increase support expenditure and capital outplay expenditure could lead to overall better support and equipment for students, which might impact test scores. To make things interesting, I am not going to divide these spending amounts by the number of students; I want to see how different absolute levels of funding, which reflect state size and spending per capita, correlate with outcomes.

# %% [markdown]
# <h2>Visualization</h2>
#
# Use any graph you wish to see the relationship of your chosen outcome variable with any features you chose
#
# **Visualization 1**

# %%
# cleaning data by dropping nan values
df.dropna(subset=["AVG_MATH_8_SCORE"], inplace = True)
df.dropna(subset=["SUPPORT_SERVICES_EXPENDITURE"], inplace = True)
df.dropna(subset=["CAPITAL_OUTLAY_EXPENDITURE"], inplace = True)
df.dropna(subset=["INSTRUCTION_EXPENDITURE"], inplace = True)

# creating scatter plot
df.plot.scatter(x = "INSTRUCTION_EXPENDITURE", y = "AVG_MATH_8_SCORE")
plt.title('Average 8th Grade Math Scores Scattered Against Absolute Instruction Expenditure')
# Out:
# Text(0.5, 1.0, 'Average 8th Grade Math Scores Scattered Against Absolute Instruction Expenditure')

# %% [markdown]
# **<CAPTION FOR VIZ 1>**

# %% [markdown]
# **Visualization 2**

# %%
# old data cleaning stuff I replaced with the drop na stuff above
# data_clean_ss = df[df["SUPPORT_SERVICES_EXPENDITURE"] > 0]
# data_clean_co = data_clean_ss[data_clean_ss["CAPITAL_OUTLAY_EXPENDITURE"] > 0]
# data_clean = data_clean_co[data_clean_co["INSTRUCTION_EXPENDITURE"] > 0]


# trying out joinplot plotting capital and support spending by state
# didn't know how to add title to this one, set method to add title does not work for jointplots
sns.jointplot(data=df, x="CAPITAL_OUTLAY_EXPENDITURE", y = "SUPPORT_SERVICES_EXPENDITURE", hue="STATE", kind="kde")
# Out:
# /mnt/c/Users/Rohan/Desktop/mdst_tutorials_W22/env/lib/python3.7/site-packages/seaborn/distributions.py:1213: UserWarning: No contour levels were found within the data range.
#   **contour_kws,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_238/3314320114.py in <module>
#       5
#       6
# ----> 7 sns.jointplot(data=df, x="CAPITAL_OUTLAY_EXPENDITURE", y = "SUPPORT_SERVICES_EXPENDITURE", hue="STATE", kind="kde").set(title="Differnt states by support and capital expeditures")
#
# /mnt/c/Users/Rohan/Desktop/mdst_tutorials_W22/env/lib/python3.7/site-packages/seaborn/axisgrid.py in set(self, **kwargs)
#      34     def set(self, **kwargs):
#      35         """Set attributes on each subplot Axes."""
# ---> 36         for ax in self.axes.flat:
#      37             if ax is not None:  # Handle removed axes
#      38                 ax.set(**kwargs)
#
# ...

# %% [markdown]
# **<CAPTION FOR VIZ 2>**

# %% [markdown]
# <h2> Data Creation </h2>
#
# _Use this space to create train/test data_

# %%
from sklearn.model_selection import train_test_split

# %%
# setting x and y

X = df[['INSTRUCTION_EXPENDITURE','CAPITAL_OUTLAY_EXPENDITURE','SUPPORT_SERVICES_EXPENDITURE']].dropna()
y = df.loc[X.index]['AVG_MATH_8_SCORE']

# %%
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=.4, random_state=0)

# %% [markdown]
# <h2> Prediction </h2>

# %% [markdown]
# ML Models Resource: https://medium.com/@vijaya.beeravalli/comparison-of-machine-learning-classification-models-for-credit-card-default-data-c3cf805c9a5a

# %% [markdown]
# Chosen ML task: REGRESSION

# %%
# import your sklearn class here

from sklearn.linear_model import LinearRegression

# %%
# create your model here
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
# Out:
# [ 4.58045752e-08 -1.99092857e-06  7.55214453e-07]

# %%
# FOR CLASSIFICATION ONLY:
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(model, X_test, y_test,
                         cmap=plt.cm.Blues)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_238/1865935489.py in <module>
#       3
#       4 plot_confusion_matrix(model, X_test, y_test,
# ----> 5                          cmap=plt.cm.Blues)
#
# /mnt/c/Users/Rohan/Desktop/mdst_tutorials_W22/env/lib/python3.7/site-packages/sklearn/utils/deprecation.py in wrapped(*args, **kwargs)
#      86         def wrapped(*args, **kwargs):
#      87             warnings.warn(msg, category=FutureWarning)
# ---> 88             return fun(*args, **kwargs)
#      89
#      90         wrapped.__doc__ = self._update_doc(wrapped.__doc__)
#
# /mnt/c/Users/Rohan/Desktop/mdst_tutorials_W22/env/lib/python3.7/site-packages/sklearn/metrics/_plot/confusion_matrix.py in plot_confusion_matrix(estimator, X, y_true, labels, sample_weight, normalize, display_labels, include_values, xticks_rotation, values_format, cmap, ax, colorbar)
# ...

# %%
# FOR REGRESSION ONLY: (pick a single column to visualize results)

# Results from this graph _should not_ be used as a part of your results -- it is just here to help with intuition. 
# Instead, look at the error values and individual intercepts.


col_name = "INSTRUCTION_EXPENDITURE"
col_index = X_train.columns.get_loc(col_name)

f = plt.figure(figsize=(12,6))
plt.scatter(X_train[col_name], y_train, color = "red")
plt.scatter(X_train[col_name], model.predict(X_train), color = "green")
plt.scatter(X_test[col_name], model.predict(X_test), color = "blue")

new_x = np.linspace(X_train[col_name].min(),X_train[col_name].max(),200)
intercept = model.predict([X_train.sort_values(col_name).iloc[0]]) - X_train[col_name].min()*model.coef_[col_index]
plt.plot(new_x, intercept+new_x*model.coef_[col_index])

plt.legend(['controlled model','true training','predicted training','predicted testing'])
plt.xlabel(col_name)
plt.ylabel("Average 8th grade math score")

# printing coefficients and error
print(model.coef_)
print(np.mean(np.abs(model.predict(X_test)-y_test)))
# Out:
# /mnt/c/Users/Rohan/Desktop/mdst_tutorials_W22/env/lib/python3.7/site-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# [ 4.58045752e-08 -1.99092857e-06  7.55214453e-07]
# 8.034779626809597

# %% [markdown]
# <h2> Summary </h2>

# %% [markdown]
# I set out to use machine learning to determine the impact of instruction expenditure, capital outlay expenditure and support services expenditure on average eighth grade math scores. I analyzed absolute spending in each category instead of spending per capita, for absolute spending represents a combination of the size of a state and the amount per student it funds education; I wonderered if any interesting patterns might emerge when looking at the data this way. I chose a regression model because I wanted to see quantitatively how each of my variables impacted test scores, and I specifically chose linear regression because it was a model I was somewhat familiar with from everyday life.
#
# Based on my coefficients, it seems as though absolute instruction and support spending correlate positively with test scores, while capital outlay spending correlates negatively. Yet, all of these coefficients were quite small, which, along with the large mean error of around 8, leads me to question whether the variables I chose had any meaningful impact on test scores. Ultimately, my methodology of using absolute rather than per-student funding levels was likely flawed and unhelpful, leading to the low coefficients and high error in my model, which means we likely learned little from this analysis and model.
